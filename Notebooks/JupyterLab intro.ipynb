# %%
x = 1
print(x)
# Out:
# 1

# %%
y = 5 
print(y)
# Out:
# 5

# %%
print(x+y)
# Out:
# 6

# %% [markdown]
# # Heading1
# ## Heading2
# ### Heading3
# #### Heading4
# ##### Heading5
# ###### Heading6
#
# *italics*
#
# **bold**
#
# - unordered list
# - unordered list
#
# 1. ordered list
# 2. ordered list
#
# > blockquote
#
# ___
#
# Type some `inline code` then the rest of your text.
#
# Or type in a block of code
# ```
# using 3 back ticks
# then ending with 3 more back ticks
# ```
#
# The rest of your text here.
#
# Create equations $ x^2 $ using LaTeX.
#
# www.jupyter.org (typing URL will automaticly convert it to a link)
# or create customized hyperlinks using [link text](www.jupyter.org)
